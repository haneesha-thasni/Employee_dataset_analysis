# %% [markdown]
# # Analysis of Employee Dataset

# %% [markdown]
# ## Introduction:
# This presentation explores an employee dataset to understand workforce trends, including demographics, job roles, and attrition. By analyzing this data, we aim to gain insights into factors influencing employee satisfaction and turnover. This will help HR departments make informed decisions to enhance employee retention and improve workplace satisfaction.

# %% [markdown]
# ## Objective:
# * Understand employee demographics and job characteristics.
# * Analyze trends in attrition and employee satisfaction.
# * Identify key factors impacting employee retention.
# * Provide insights to support HR decision-making.

# %% [markdown]
# ## Data Description Employee
#
# •	EmployeeID: Unique identifier for each employee.
#
# •	FirstName: The first name of the employee.
#
# •	LastName: The last name of the employee.
#
# •	Gender: The gender of the employee.
#
# •	Age: The age of the employee.
#
# •	BusinessTravel: The frequency of business travel for the employee.
#
# •	Department: The department in which the employee works.
#
# •	DistanceFromHome (KM): The distance between the employee's home and workplace in kilometers.
#
# •	State: The state in which the employee resides.
#
# •	Ethnicity: The ethnicity of the employee.
#
# •	MaritalStatus: The marital status of the employee.
#
# •	Salary: The annual salary of the employee.
#
# •	StockOptionLevel: The level of stock options granted to the employee.
#
# •	OverTime: Whether the employee works overtime (Yes/No).
#
# •	HireDate: The date the employee was hired.
#
# •	Attrition: Whether the employee has left the company (Yes/No).
#
# •	YearsAtCompany: The number of years the employee has been with the company.
#
# •	YearsInMostRecentRole: The number of years the employee has been in their most recent role.
#
# •	YearsSinceLastPromotion: The number of years since the employee's last promotion.
#
# •	YearsWithCurrManager: The number of years the employee has worked with their current manager.

# %% [markdown]
# ## Import dataset

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Employee.csv')

# %%
df
# Out:
#      EmployeeID   FirstName     LastName      Gender  Age BusinessTravel  \
# 0     3012-1A41    Leonelle        Simco      Female   30    Some Travel
# 1     CBCB-9C9D     Leonerd        Aland        Male   38    Some Travel
# 2     95D7-1CE9       Ahmed        Sykes        Male   43    Some Travel
# 3     47A0-559B  Ermentrude       Berrie  Non-Binary   39    Some Travel
# 4     42CC-040A       Stace       Savege      Female   29    Some Travel
# ...         ...         ...          ...         ...  ...            ...
# 1465  467E-977A         Jud    Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624        Marc       Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928     Rudolph  MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9      Merill          Agg        Male   21    Some Travel
# 1469  84D4-D4C3       Naoma      Hebbard      Female   20     No Travel
#
#            Department  DistanceFromHome (KM) State                  Ethnicity  \
# ...

# %% [markdown]
# ### It is a 2 dimension dataset

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# #### to retreive the first specified number of rows in the dataset

# %%
df.head(6)
# Out:
#   EmployeeID    FirstName LastName      Gender  Age BusinessTravel  \
# 0  3012-1A41     Leonelle    Simco      Female   30    Some Travel
# 1  CBCB-9C9D      Leonerd    Aland        Male   38    Some Travel
# 2  95D7-1CE9        Ahmed    Sykes        Male   43    Some Travel
# 3  47A0-559B   Ermentrude   Berrie  Non-Binary   39    Some Travel
# 4  42CC-040A        Stace   Savege      Female   29    Some Travel
# 5  C219-6C2E  Clerkclaude  Hinkins        Male   34    Some Travel
#
#         Department  DistanceFromHome (KM) State  \
# 0            Sales                     27    IL
# 1            Sales                     23    CA
# 2  Human Resources                     29    CA
# 3       Technology                     12    IL
# 4  Human Resources                     29    CA
# 5            Sales                     30    NY
#
#                          Ethnicity  ...  MaritalStatus  Salary  \
# 0                            White  ...       Divorced  102059
# ...

# %% [markdown]
# #### To retrieve the last rows, in this case 5 rows is default

# %%
df.tail()
# Out:
#      EmployeeID FirstName     LastName      Gender  Age BusinessTravel  \
# 1465  467E-977A       Jud    Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624      Marc       Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928   Rudolph  MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9    Merill          Agg        Male   21    Some Travel
# 1469  84D4-D4C3     Naoma      Hebbard      Female   20     No Travel
#
#       Department  DistanceFromHome (KM) State                  Ethnicity  ...  \
# 1465  Technology                     28    CA  Black or African American  ...
# 1466  Technology                      8    CA  Black or African American  ...
# 1467       Sales                      4    CA  Black or African American  ...
# 1468  Technology                      7    CA  Black or African American  ...
# 1469  Technology                     28    CA  Black or African American  ...
#
# ...

# %% [markdown]
# #### To find the number of rows and columns

# %%
df.shape
# Out:
# (1470, 23)

# %% [markdown]
# #### To finf the total number of items in the dataset

# %%
df.size
# Out:
# 33810

# %% [markdown]
# # Information of the dataset
#
# * Columns= 23
# * Rows= 1470
# * Cleaned data- no null values
# * Data types
#    * integer = 9
#    * object = 14
# * No duplicate values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               1470 non-null   object
#  1   FirstName                1470 non-null   object
#  2   LastName                 1470 non-null   object
#  3   Gender                   1470 non-null   object
#  4   Age                      1470 non-null   int64
#  5   BusinessTravel           1470 non-null   object
#  6   Department               1470 non-null   object
#  7   DistanceFromHome (KM)    1470 non-null   int64
#  8   State                    1470 non-null   object
#  9   Ethnicity                1470 non-null   object
#  10  Education                1470 non-null   int64
#  11  EducationField           1470 non-null   object
#  12  JobRole                  1470 non-null   object
#  13  MaritalStatus            1470 non-null   object
# ...

# %% [markdown]
# #### To check number of null values

# %%
df.isnull().sum()
# Out:
# EmployeeID                 0
# FirstName                  0
# LastName                   0
# Gender                     0
# Age                        0
# BusinessTravel             0
# Department                 0
# DistanceFromHome (KM)      0
# State                      0
# Ethnicity                  0
# Education                  0
# EducationField             0
# JobRole                    0
# MaritalStatus              0
# Salary                     0
# StockOptionLevel           0
# OverTime                   0
# HireDate                   0
# Attrition                  0
# YearsAtCompany             0
# YearsInMostRecentRole      0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %% [markdown]
# ## Description of the dataset
#
# * count
# * mean
# * standard deviation
# * minimum
# * maximum

# %%
df.describe().T
# Out:
#                           count           mean            std      min  \
# Age                      1470.0      28.989796       7.993055     18.0
# DistanceFromHome (KM)    1470.0      22.502721      12.811124      1.0
# Education                1470.0       2.912925       1.024165      1.0
# Salary                   1470.0  112956.497959  103342.889222  20387.0
# StockOptionLevel         1470.0       0.793878       0.852077      0.0
# YearsAtCompany           1470.0       4.562585       3.288048      0.0
# YearsInMostRecentRole    1470.0       2.293197       2.539093      0.0
# YearsSinceLastPromotion  1470.0       3.440816       2.945194      0.0
# YearsWithCurrManager     1470.0       2.239456       2.505774      0.0
#
#                              25%      50%        75%       max
# Age                         23.0     26.0      34.00      51.0
# DistanceFromHome (KM)       12.0     22.0      33.00      45.0
# Education                    2.0      3.0       4.00       5.0
# ...

# %%
df.describe(include='all').T
# Out:
#                           count unique               top  freq           mean  \
# EmployeeID                 1470   1470         3012-1A41     1            NaN
# FirstName                  1470   1334           Murdock     3            NaN
# LastName                   1470   1441            Ponten     2            NaN
# Gender                     1470      4            Female   675            NaN
# Age                      1470.0    NaN               NaN   NaN      28.989796
# BusinessTravel             1470      3       Some Travel  1043            NaN
# Department                 1470      3        Technology   961            NaN
# DistanceFromHome (KM)    1470.0    NaN               NaN   NaN      22.502721
# State                      1470      3                CA   875            NaN
# Ethnicity                  1470      7             White   860            NaN
# Education                1470.0    NaN               NaN   NaN       2.912925
# ...

# %%
df.describe(include='object').T
# Out:
#                count unique               top  freq
# EmployeeID      1470   1470         3012-1A41     1
# FirstName       1470   1334           Murdock     3
# LastName        1470   1441            Ponten     2
# Gender          1470      4            Female   675
# BusinessTravel  1470      3       Some Travel  1043
# Department      1470      3        Technology   961
# State           1470      3                CA   875
# Ethnicity       1470      7             White   860
# EducationField  1470      9  Computer Science   440
# JobRole         1470     13   Sales Executive   327
# MaritalStatus   1470      3           Married   624
# OverTime        1470      2                No  1054
# HireDate        1470   1192        2016-10-04     4
# Attrition       1470      2                No  1233

# %% [markdown]
# ### to find number of unique values

# %%
df.nunique()
# Out:
# EmployeeID                 1470
# FirstName                  1334
# LastName                   1441
# Gender                        4
# Age                          34
# BusinessTravel                3
# Department                    3
# DistanceFromHome (KM)        45
# State                         3
# Ethnicity                     7
# Education                     5
# EducationField                9
# JobRole                      13
# MaritalStatus                 3
# Salary                     1455
# StockOptionLevel              4
# OverTime                      2
# HireDate                   1192
# Attrition                     2
# YearsAtCompany               11
# YearsInMostRecentRole        11
# YearsSinceLastPromotion      11
# YearsWithCurrManager         11
# dtype: int64

# %% [markdown]
# ## Find unique value

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male', 'Non-Binary', 'Prefer Not To Say'], dtype=object)

# %%
df['BusinessTravel'].unique()
# Out:
# array(['Some Travel', 'No Travel ', 'Frequent Traveller'], dtype=object)

# %%
for i in df.columns:
    print(i,":",df[i].unique())
# Out:
# EmployeeID : ['3012-1A41' 'CBCB-9C9D' '95D7-1CE9' ... 'EBF4-5928' '60E6-B1D9'
#  '84D4-D4C3']
# FirstName : ['Leonelle' 'Leonerd' 'Ahmed' ... 'Rudolph' 'Merill' 'Naoma']
# LastName : ['Simco' 'Aland' 'Sykes' ... 'MacDearmont' 'Agg' 'Hebbard']
# Gender : ['Female' 'Male' 'Non-Binary' 'Prefer Not To Say']
# Age : [30 38 43 39 29 34 42 40 31 32 35 37 33 45 36 48 47 44 28 41 46 27 26 25
#  24 23 22 21 49 50 20 19 51 18]
# BusinessTravel : ['Some Travel' 'No Travel ' 'Frequent Traveller']
# Department : ['Sales' 'Human Resources' 'Technology']
# DistanceFromHome (KM) : [27 23 29 12 30 45  3 20  4 42  8 35 21 34 19  1 17 36 37 41 25 44 22 40
#  14 15  7  5 31  9 13 38 16 39 28 32  2  6 11 33 26 43 10 18 24]
# State : ['IL' 'CA' 'NY']
# Ethnicity : ['White' 'Asian or Asian American' 'Mixed or multiple ethnic groups'
#  'Black or African American' 'Native Hawaiian ' 'Other '
#  'American Indian or Alaska Native']
# Education : [5 4 3 2 1]
# ...

# %%
df.columns
# Out:
# Index(['EmployeeID', 'FirstName', 'LastName', 'Gender', 'Age',
#        'BusinessTravel', 'Department', 'DistanceFromHome (KM)', 'State',
#        'Ethnicity', 'Education', 'EducationField', 'JobRole', 'MaritalStatus',
#        'Salary', 'StockOptionLevel', 'OverTime', 'HireDate', 'Attrition',
#        'YearsAtCompany', 'YearsInMostRecentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ## Checking Duplicates

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##  converting datatype
#
# * HireDate(object) -- to datetime format

# %%
df.dtypes
# Out:
# EmployeeID                 object
# FirstName                  object
# LastName                   object
# Gender                     object
# Age                         int64
# BusinessTravel             object
# Department                 object
# DistanceFromHome (KM)       int64
# State                      object
# Ethnicity                  object
# Education                   int64
# EducationField             object
# JobRole                    object
# MaritalStatus              object
# Salary                      int64
# StockOptionLevel            int64
# OverTime                   object
# HireDate                   object
# Attrition                  object
# YearsAtCompany              int64
# YearsInMostRecentRole       int64
# YearsSinceLastPromotion     int64
# YearsWithCurrManager        int64
# dtype: object

# %%
df['HireDate']=pd.to_datetime(df['HireDate'])

# %%
#,ethod 2) df['HireDate']=df['HireDate'].astype('datetime64[ns]')

# %%
df.dtypes
# Out:
# EmployeeID                         object
# FirstName                          object
# LastName                           object
# Gender                             object
# Age                                 int64
# BusinessTravel                     object
# Department                         object
# DistanceFromHome (KM)               int64
# State                              object
# Ethnicity                          object
# Education                           int64
# EducationField                     object
# JobRole                            object
# MaritalStatus                      object
# Salary                              int64
# StockOptionLevel                    int64
# OverTime                           object
# HireDate                   datetime64[ns]
# Attrition                          object
# YearsAtCompany                      int64
# YearsInMostRecentRole               int64
# YearsSinceLastPromotion             int64
# ...

# %% [markdown]
# # FEATURE ENGINEERING

# %% [markdown]
# ## Extracting datetime components
#
# * Year
# * Month
# * Month Name
# * Day
# * Day Name

# %%
df['HireYear']=df['HireDate'].dt.year
df['HireMonth']=df['HireDate'].dt.month
df['HireMonth_Name']=df['HireDate'].dt.month_name()
df['HireDay']=df['HireDate'].dt.day
df['HireDay_Name']=df['HireDate'].dt.day_name()

# %%
df
# Out:
#      EmployeeID   FirstName     LastName      Gender  Age BusinessTravel  \
# 0     3012-1A41    Leonelle        Simco      Female   30    Some Travel
# 1     CBCB-9C9D     Leonerd        Aland        Male   38    Some Travel
# 2     95D7-1CE9       Ahmed        Sykes        Male   43    Some Travel
# 3     47A0-559B  Ermentrude       Berrie  Non-Binary   39    Some Travel
# 4     42CC-040A       Stace       Savege      Female   29    Some Travel
# ...         ...         ...          ...         ...  ...            ...
# 1465  467E-977A         Jud    Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624        Marc       Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928     Rudolph  MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9      Merill          Agg        Male   21    Some Travel
# 1469  84D4-D4C3       Naoma      Hebbard      Female   20     No Travel
#
#            Department  DistanceFromHome (KM) State                  Ethnicity  \
# ...

# %% [markdown]
# ### Extracting new column with combining of 2 columns

# %%
df['Full_Name']=df['FirstName']+' '+df['LastName']

# %%
df
# Out:
#      EmployeeID   FirstName     LastName      Gender  Age BusinessTravel  \
# 0     3012-1A41    Leonelle        Simco      Female   30    Some Travel
# 1     CBCB-9C9D     Leonerd        Aland        Male   38    Some Travel
# 2     95D7-1CE9       Ahmed        Sykes        Male   43    Some Travel
# 3     47A0-559B  Ermentrude       Berrie  Non-Binary   39    Some Travel
# 4     42CC-040A       Stace       Savege      Female   29    Some Travel
# ...         ...         ...          ...         ...  ...            ...
# 1465  467E-977A         Jud    Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624        Marc       Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928     Rudolph  MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9      Merill          Agg        Male   21    Some Travel
# 1469  84D4-D4C3       Naoma      Hebbard      Female   20     No Travel
#
#            Department  DistanceFromHome (KM) State                  Ethnicity  \
# ...

# %%
df['FirstName']=df['FirstName']+" "+df['LastName']

# %%
df
# Out:
#      EmployeeID            FirstName     LastName      Gender  Age  \
# 0     3012-1A41       Leonelle Simco        Simco      Female   30
# 1     CBCB-9C9D        Leonerd Aland        Aland        Male   38
# 2     95D7-1CE9          Ahmed Sykes        Sykes        Male   43
# 3     47A0-559B    Ermentrude Berrie       Berrie  Non-Binary   39
# 4     42CC-040A         Stace Savege       Savege      Female   29
# ...         ...                  ...          ...         ...  ...
# 1465  467E-977A        Jud Melanaphy    Melanaphy        Male   20
# 1466  6FB9-A624          Marc Calver       Calver  Non-Binary   27
# 1467  EBF4-5928  Rudolph MacDearmont  MacDearmont        Male   21
# 1468  60E6-B1D9           Merill Agg          Agg        Male   21
# 1469  84D4-D4C3        Naoma Hebbard      Hebbard      Female   20
#
#      BusinessTravel       Department  DistanceFromHome (KM) State  \
# 0       Some Travel            Sales                     27    IL
# ...

# %% [markdown]
# ### Drop/Remove a column

# %%
df.drop(columns='LastName',axis=1,inplace=True)

# %% [markdown]
# ### Rename the column name

# %%
df.rename({'FirstName':'EmployeeName'},inplace=True,axis=1)

# %%
df
# Out:
#      EmployeeID         EmployeeName      Gender  Age BusinessTravel  \
# 0     3012-1A41       Leonelle Simco      Female   30    Some Travel
# 1     CBCB-9C9D        Leonerd Aland        Male   38    Some Travel
# 2     95D7-1CE9          Ahmed Sykes        Male   43    Some Travel
# 3     47A0-559B    Ermentrude Berrie  Non-Binary   39    Some Travel
# 4     42CC-040A         Stace Savege      Female   29    Some Travel
# ...         ...                  ...         ...  ...            ...
# 1465  467E-977A        Jud Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624          Marc Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928  Rudolph MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9           Merill Agg        Male   21    Some Travel
# 1469  84D4-D4C3        Naoma Hebbard      Female   20     No Travel
#
#            Department  DistanceFromHome (KM) State                  Ethnicity  \
# ...

# %%
df.drop(columns='Full_Name',axis=1,inplace=True)

# %%
df
# Out:
#      EmployeeID         EmployeeName      Gender  Age BusinessTravel  \
# 0     3012-1A41       Leonelle Simco      Female   30    Some Travel
# 1     CBCB-9C9D        Leonerd Aland        Male   38    Some Travel
# 2     95D7-1CE9          Ahmed Sykes        Male   43    Some Travel
# 3     47A0-559B    Ermentrude Berrie  Non-Binary   39    Some Travel
# 4     42CC-040A         Stace Savege      Female   29    Some Travel
# ...         ...                  ...         ...  ...            ...
# 1465  467E-977A        Jud Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624          Marc Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928  Rudolph MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9           Merill Agg        Male   21    Some Travel
# 1469  84D4-D4C3        Naoma Hebbard      Female   20     No Travel
#
#            Department  DistanceFromHome (KM) State                  Ethnicity  \
# ...

# %%
df.value_counts().sum()
# Out:
# 1470

# %% [markdown]
# ## Filtering
#
# * Basic filtering
# * loc
# * iloc

# %%
df.columns
# Out:
# Index(['EmployeeID', 'EmployeeName', 'Gender', 'Age', 'BusinessTravel',
#        'Department', 'DistanceFromHome (KM)', 'State', 'Ethnicity',
#        'Education', 'EducationField', 'JobRole', 'MaritalStatus', 'Salary',
#        'StockOptionLevel', 'OverTime', 'HireDate', 'Attrition',
#        'YearsAtCompany', 'YearsInMostRecentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'HireYear', 'HireMonth', 'HireMonth_Name',
#        'HireDay', 'HireDay_Name'],
#       dtype='object')

# %%
df['YearsSinceLastPromotion'].unique()
# Out:
# array([ 9, 10,  1,  7,  6,  4,  8,  5,  2,  3,  0], dtype=int64)

# %%
# Q) Which employees over the age of 35 have been promoted within the last 5 years, and what are their current job roles?
job_status=df[['EmployeeName','JobRole']][(df['Age']>35)&(df['YearsSinceLastPromotion']<5)]
job_status
# Out:
#                          EmployeeName                    JobRole
# 7                        Joyan Brason            Sales Executive
# 13                        Edna Alison          Software Engineer
# 57                        Amye Townes             Data Scientist
# 83                     Muffin Ellcome          Software Engineer
# 95    Jodie Le Breton De La Vieuville  Machine Learning Engineer
# ...                               ...                        ...
# 1387                Greer MacDearmaid            Sales Executive
# 1405                     Erny Waywell   Senior Software Engineer
# 1418                       Layton Ord            Sales Executive
# 1436                      Ava Galland               HR Executive
# 1463                    Symon Raisher   Senior Software Engineer
#
# [136 rows x 2 columns]

# %%
# Q) filter the rows in a DataFrame to display only the employees in the Technology department who have a salary greater than 70,000?
tech_salary_high=df[(df['Department']=='Technology')&(df['Salary']>70000)]
tech_salary_high
# Out:
#      EmployeeID       EmployeeName             Gender  Age  \
# 3     47A0-559B  Ermentrude Berrie         Non-Binary   39
# 6     D906-B674         Uta Melmar             Female   42
# 10    73CF-4956      Hannis Waslin             Female   32
# 11    277A-A6FA    Annabela Pablos             Female   35
# 14    97F4-0B14      Vernen Powner               Male   33
# ...         ...                ...                ...  ...
# 1453  23B5-93C9   Carlita Ivanenko  Prefer Not To Say   31
# 1454  9160-043F     Jemie Tasseler             Female   29
# 1456  542E-321D    Spencer Gabitis               Male   30
# 1463  8B55-CBEC      Symon Raisher               Male   40
# 1466  6FB9-A624        Marc Calver         Non-Binary   27
#
#           BusinessTravel  Department  DistanceFromHome (KM) State  \
# 3            Some Travel  Technology                     12    IL
# 6             No Travel   Technology                     45    NY
# ...

# %%
# Q) filter the rows in a DataFrame to display employees who are either in the Human Resources or Sales department and are older than 40?
dep_sls_hr= df[((df['Department'] == 'Human Resources') | (df['Department'] == 'Sales')) & (df['Age'] > 40)]
dep_sls_hr
# Out:
#      EmployeeID       EmployeeName  Gender  Age      BusinessTravel  \
# 2     95D7-1CE9        Ahmed Sykes    Male   43         Some Travel
# 16    BD1B-53A3     Wendall Dryden    Male   43         Some Travel
# 17    DFA9-990E       Cale Holston    Male   43          No Travel
# 23    B3AF-7E58     Elvira Ianelli  Female   45         Some Travel
# 29    D565-284D     Bessie Bellson  Female   47  Frequent Traveller
# ...         ...                ...     ...  ...                 ...
# 1282  0BEE-FC20    Sherill Covotti  Female   49         Some Travel
# 1304  0C54-705D      Grata Yannoni  Female   50         Some Travel
# 1308  A663-B3DF      Wynny Pechell  Female   41  Frequent Traveller
# 1372  C3C0-349E         Isac Dreus    Male   45         Some Travel
# 1387  921D-AE10  Greer MacDearmaid  Female   46          No Travel
#
#            Department  DistanceFromHome (KM) State  \
# 2     Human Resources                     29    CA
# ...

# %%
# Q) filter the employee dataset to select only the employees name and YearsAtCompany who are over 30 years old, work in the Sales department, and have a salary greater than 80,000?
sls_age30_slryhigh=df[["EmployeeName","YearsAtCompany"]][(df['Age'] > 30) & (df['Department'] == 'Sales') & (df['Salary'] > 80000)]
sls_age30_slryhigh
# Out:
#               EmployeeName  YearsAtCompany
# 1            Leonerd Aland              10
# 5      Clerkclaude Hinkins              10
# 7             Joyan Brason              10
# 8         Alix Blazejewski              10
# 12             Torey Abram              10
# ...                    ...             ...
# 1404       Torre Blazynski               0
# 1418            Layton Ord               0
# 1420       Kane Skillicorn               0
# 1433        Tracey Joynson               0
# 1435  Selestina Ferrarello               0
#
# [132 rows x 2 columns]

# %%
# Q) select employees who work in the 'Human Resources' department, are younger than 35, and travel frequently for business?
hr_age35_frqtrvl = df[(df['Department'] == 'Human Resources') & (df['Age'] < 35) & (df['BusinessTravel'] == 'Frequent Traveller')]
hr_age35_frqtrvl
# Out:
#      EmployeeID      EmployeeName      Gender  Age      BusinessTravel  \
# 377   B6EC-313E     Corbin Gooddy        Male   26  Frequent Traveller
# 425   F5E3-48BB     Zenia Rattery      Female   25  Frequent Traveller
# 997   0CFA-28A3        Duff Rioch        Male   21  Frequent Traveller
# 1145  55A7-8D82       Allyn Glyde  Non-Binary   23  Frequent Traveller
# 1223  B0C8-E3DF  Eleanor Escalero      Female   19  Frequent Traveller
# 1317  BEBB-3E92    Flinn Redferne        Male   24  Frequent Traveller
# 1337  F469-0427    Krissie Albery      Female   19  Frequent Traveller
#
#            Department  DistanceFromHome (KM) State  \
# 377   Human Resources                     17    CA
# 425   Human Resources                      3    CA
# 997   Human Resources                     42    CA
# 1145  Human Resources                     34    NY
# 1223  Human Resources                     24    IL
# 1317  Human Resources                     17    CA
# ...

# %%
# Q) select the first 11 rows of the DataFrame and all columns starting from 'Employee_Name' to the end?
df1=df.loc[0:10,'EmployeeName':]
df1
# Out:
#            EmployeeName      Gender  Age      BusinessTravel       Department  \
# 0        Leonelle Simco      Female   30         Some Travel            Sales
# 1         Leonerd Aland        Male   38         Some Travel            Sales
# 2           Ahmed Sykes        Male   43         Some Travel  Human Resources
# 3     Ermentrude Berrie  Non-Binary   39         Some Travel       Technology
# 4          Stace Savege      Female   29         Some Travel  Human Resources
# 5   Clerkclaude Hinkins        Male   34         Some Travel            Sales
# 6            Uta Melmar      Female   42          No Travel        Technology
# 7          Joyan Brason      Female   40         Some Travel            Sales
# 8      Alix Blazejewski        Male   38         Some Travel            Sales
# 9          Kayley Snoad      Female   31  Frequent Traveller       Technology
# 10        Hannis Waslin      Female   32         Some Travel       Technology
#
# ...

# %%
# Q) acessing all rows and columns from the Employee_Name to Department
df2=df.loc[:,'EmployeeName':'Department']
df2
# Out:
#              EmployeeName      Gender  Age BusinessTravel       Department
# 0          Leonelle Simco      Female   30    Some Travel            Sales
# 1           Leonerd Aland        Male   38    Some Travel            Sales
# 2             Ahmed Sykes        Male   43    Some Travel  Human Resources
# 3       Ermentrude Berrie  Non-Binary   39    Some Travel       Technology
# 4            Stace Savege      Female   29    Some Travel  Human Resources
# ...                   ...         ...  ...            ...              ...
# 1465        Jud Melanaphy        Male   20    Some Travel       Technology
# 1466          Marc Calver  Non-Binary   27    Some Travel       Technology
# 1467  Rudolph MacDearmont        Male   21    Some Travel            Sales
# 1468           Merill Agg        Male   21    Some Travel       Technology
# 1469        Naoma Hebbard      Female   20     No Travel        Technology
#
# [1470 rows x 5 columns]

# %%
# method 2
df.loc[:,['EmployeeName','Gender','Age','BusinessTravel','Department']]
# Out:
#              EmployeeName      Gender  Age BusinessTravel       Department
# 0          Leonelle Simco      Female   30    Some Travel            Sales
# 1           Leonerd Aland        Male   38    Some Travel            Sales
# 2             Ahmed Sykes        Male   43    Some Travel  Human Resources
# 3       Ermentrude Berrie  Non-Binary   39    Some Travel       Technology
# 4            Stace Savege      Female   29    Some Travel  Human Resources
# ...                   ...         ...  ...            ...              ...
# 1465        Jud Melanaphy        Male   20    Some Travel       Technology
# 1466          Marc Calver  Non-Binary   27    Some Travel       Technology
# 1467  Rudolph MacDearmont        Male   21    Some Travel            Sales
# 1468           Merill Agg        Male   21    Some Travel       Technology
# 1469        Naoma Hebbard      Female   20     No Travel        Technology
#
# [1470 rows x 5 columns]

# %%
# Q) extract the names, states, marital status, distance from home, departments, and job roles of employees who are older than 45 and work overtime?
df3=df.loc[(df['Age']>45)&(df['OverTime']=='Yes'),['EmployeeName','State','MaritalStatus','DistanceFromHome (KM)','Department','JobRole']]
df3
# Out:
#           EmployeeName State MaritalStatus  DistanceFromHome (KM)  \
# 92        Addison Elfe    CA       Married                     11
# 96       Darice Excell    NY        Single                      5
# 112        Ashli Hales    CA       Married                     36
# 143        Conn Mouser    IL      Divorced                     45
# 156       Mimi Mawditt    NY        Single                     16
# 159      Albina Baston    NY       Married                     24
# 188       Joya Hefford    NY       Married                     32
# 338        Baird Trays    NY      Divorced                      9
# 341    Marilee Moreton    CA       Married                     21
# 838      Marlin Egdell    CA      Divorced                     26
# 998   Filide Summerlie    CA       Married                      8
# 1105    April Brunicke    CA       Married                     15
# 1107    Emmie Lauchlan    CA       Married                     23
#
# ...

# %%
# Q) select rows 100 to 500 and the columns from 'EmployeeName' to 'Education' in the DataFrame?
df4=df.loc[100:500,'EmployeeName':'Education']
df4
# Out:
#              EmployeeName      Gender  Age BusinessTravel  Department  \
# 100       Skipper Sambles        Male   47    Some Travel  Technology
# 101    Emmerich Wallicker        Male   47     No Travel        Sales
# 102          Horst Mynett        Male   36    Some Travel  Technology
# 103  Benyamin Wasielewicz        Male   43     No Travel   Technology
# 104         Pierce Birkby        Male   38    Some Travel  Technology
# ..                    ...         ...  ...            ...         ...
# 496         Nanine Barrie      Female   26     No Travel   Technology
# 497       Meade Quinnelly        Male   25    Some Travel  Technology
# 498      Alister Gianullo        Male   27    Some Travel  Technology
# 499         Magnum Dublin  Non-Binary   27    Some Travel  Technology
# 500        Ichabod Mabbot        Male   28    Some Travel       Sales
#
#      DistanceFromHome (KM) State                        Ethnicity  Education
# ...

# %%
# Q) filter the records of employees who have left the company and have spent 5 or more years with their current manager
df5=df.loc[(df['Attrition']=='Yes')&(df['YearsWithCurrManager']>=5)]
df5
# Out:
#     EmployeeID       EmployeeName  Gender  Age      BusinessTravel  \
# 4    42CC-040A       Stace Savege  Female   29         Some Travel
# 20   D7EE-56FC     Zsa zsa Evered  Female   39  Frequent Traveller
# 53   151D-1FF2           Kai Lush  Female   34  Frequent Traveller
# 112  E1B4-9AA1        Ashli Hales  Female   46         Some Travel
# 114  5237-1B85      Faydra Losbie  Female   28         Some Travel
# 127  FE2B-3DC7  Mattie Wippermann  Female   28         Some Travel
# 143  8EE9-E86D        Conn Mouser    Male   46         Some Travel
# 147  DFE3-6FA7     Eulalie Critch  Female   43  Frequent Traveller
# 245  4B6E-3C21     Heidie McCrone  Female   32         Some Travel
# 251  327B-F6D3         Codee Jean  Female   37         Some Travel
# 275  12F7-BCBB     Clea MacCartan  Female   48  Frequent Traveller
# 379  5A04-0EB4    Debbie Martinho  Female   27  Frequent Traveller
# 399  D4D5-27FB       Bengt Keaves    Male   29         Some Travel
# ...

# %%
# Q) retrieve the first 101 rows and the first 10 columns from the DataFrame
df.iloc[0:101,0:10]
# Out:
#     EmployeeID          EmployeeName      Gender  Age      BusinessTravel  \
# 0    3012-1A41        Leonelle Simco      Female   30         Some Travel
# 1    CBCB-9C9D         Leonerd Aland        Male   38         Some Travel
# 2    95D7-1CE9           Ahmed Sykes        Male   43         Some Travel
# 3    47A0-559B     Ermentrude Berrie  Non-Binary   39         Some Travel
# 4    42CC-040A          Stace Savege      Female   29         Some Travel
# ..         ...                   ...         ...  ...                 ...
# 96   2962-039F         Darice Excell      Female   47         Some Travel
# 97   21CB-EF3E  Eleanora Thornbarrow      Female   36         Some Travel
# 98   9727-BC84      Murdock Spaduzza        Male   31         Some Travel
# 99   68FB-06A7         Elle Balcombe      Female   43  Frequent Traveller
# 100  74F2-5C55       Skipper Sambles        Male   47         Some Travel
#
#           Department  DistanceFromHome (KM) State  \
# ...

# %%
# Q) extract the data from specific columns (2nd, 6th, 10th, 11th, 12th, and 17th) for all rows in the DataFrame
df.iloc[:,[1,5,9,10,11,16]]
# Out:
#              EmployeeName       Department  Education       EducationField  \
# 0          Leonelle Simco            Sales          5            Marketing
# 1           Leonerd Aland            Sales          4            Marketing
# 2             Ahmed Sykes  Human Resources          4           Marketing
# 3       Ermentrude Berrie       Technology          3     Computer Science
# 4            Stace Savege  Human Resources          2     Technical Degree
# ...                   ...              ...        ...                  ...
# 1465        Jud Melanaphy       Technology          2     Computer Science
# 1466          Marc Calver       Technology          3     Business Studies
# 1467  Rudolph MacDearmont            Sales          4            Marketing
# 1468           Merill Agg       Technology          3  Information Systems
# 1469        Naoma Hebbard       Technology          2     Computer Science
#
#                        JobRole   HireDate
# ...

# %%
# Q) select all rows of the DataFrame but only display columns starting from the second column(EmployeeName) to the end?
df.iloc[:,1:]
# Out:
#              EmployeeName      Gender  Age BusinessTravel       Department  \
# 0          Leonelle Simco      Female   30    Some Travel            Sales
# 1           Leonerd Aland        Male   38    Some Travel            Sales
# 2             Ahmed Sykes        Male   43    Some Travel  Human Resources
# 3       Ermentrude Berrie  Non-Binary   39    Some Travel       Technology
# 4            Stace Savege      Female   29    Some Travel  Human Resources
# ...                   ...         ...  ...            ...              ...
# 1465        Jud Melanaphy        Male   20    Some Travel       Technology
# 1466          Marc Calver  Non-Binary   27    Some Travel       Technology
# 1467  Rudolph MacDearmont        Male   21    Some Travel            Sales
# 1468           Merill Agg        Male   21    Some Travel       Technology
# 1469        Naoma Hebbard      Female   20     No Travel        Technology
#
# ...

# %% [markdown]
# ## Sorting

# %%
df.columns
# Out:
# Index(['EmployeeID', 'EmployeeName', 'Gender', 'Age', 'BusinessTravel',
#        'Department', 'DistanceFromHome (KM)', 'State', 'Ethnicity',
#        'Education', 'EducationField', 'JobRole', 'MaritalStatus', 'Salary',
#        'StockOptionLevel', 'OverTime', 'HireDate', 'Attrition',
#        'YearsAtCompany', 'YearsInMostRecentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'HireYear', 'HireMonth', 'HireMonth_Name',
#        'HireDay', 'HireDay_Name'],
#       dtype='object')

# %%
# Q) sort the DataFrame in ascending order based on the 'Salary' column
df.sort_values(by='Salary',ascending=True)
# Out:
#      EmployeeID              EmployeeName      Gender  Age  \
# 621   ADF8-AD57              Trip Bennell        Male   27
# 1366  543B-0EE5       Theodore Parrington        Male   20
# 1346  812D-7475            Lucius Plimmer        Male   20
# 1111  D676-2084            Shannon Kuhnel        Male   21
# 334   45D7-5C8A             Artemus Boyet        Male   26
# ...         ...                       ...         ...  ...
# 1054  98EE-8547              Lock Pierson        Male   31
# 1167  1A7C-19DB              Randi Oswick      Female   39
# 65    5731-90E6  Leonidas Clarke-Williams  Non-Binary   35
# 397   DF63-0D3C               Roda Costin      Female   28
# 385   17AE-E715            Norbie Mosdill        Male   31
#
#           BusinessTravel       Department  DistanceFromHome (KM) State  \
# 621          Some Travel       Technology                     28    CA
# 1366         Some Travel       Technology                     39    NY
# ...

# %%
# Q) sort a DataFrame to display the 'EmployeeName,' 'Department,' 'YearsAtCompany,' and 'YearsSinceLastPromotion' columns, sorting by 'YearsAtCompany' in descending order and 'YearsSinceLastPromotion' in ascending order?
sort=df[['EmployeeName','Department','YearsAtCompany','YearsSinceLastPromotion']].sort_values(by=['YearsAtCompany','YearsSinceLastPromotion'],ascending=[False,True])
sort
# Out:
#                          EmployeeName       Department  YearsAtCompany  \
# 91                     Nikolas Leslie            Sales              10
# 95    Jodie Le Breton De La Vieuville       Technology              10
# 13                        Edna Alison       Technology              10
# 27                      Collen Sedman  Human Resources              10
# 38                 Pasquale Abreheart       Technology              10
# ...                               ...              ...             ...
# 1465                    Jud Melanaphy       Technology               0
# 1466                      Marc Calver       Technology               0
# 1467              Rudolph MacDearmont            Sales               0
# 1468                       Merill Agg       Technology               0
# 1469                    Naoma Hebbard       Technology               0
#
#       YearsSinceLastPromotion
# 91                          1
# 95                          1
# ...

# %% [markdown]
# ## isin()

# %%
# Q) filter the DataFrame to show only the records of employees who work in the 'Technology' department
dep_tech=df[df['Department'].isin(['Technology'])]
dep_tech
# Out:
#      EmployeeID       EmployeeName      Gender  Age      BusinessTravel  \
# 3     47A0-559B  Ermentrude Berrie  Non-Binary   39         Some Travel
# 6     D906-B674         Uta Melmar      Female   42          No Travel
# 9     5476-CA0D       Kayley Snoad      Female   31  Frequent Traveller
# 10    73CF-4956      Hannis Waslin      Female   32         Some Travel
# 11    277A-A6FA    Annabela Pablos      Female   35         Some Travel
# ...         ...                ...         ...  ...                 ...
# 1463  8B55-CBEC      Symon Raisher        Male   40         Some Travel
# 1465  467E-977A      Jud Melanaphy        Male   20         Some Travel
# 1466  6FB9-A624        Marc Calver  Non-Binary   27         Some Travel
# 1468  60E6-B1D9         Merill Agg        Male   21         Some Travel
# 1469  84D4-D4C3      Naoma Hebbard      Female   20          No Travel
#
#       Department  DistanceFromHome (KM) State                  Ethnicity  \
# ...

# %%
# Q) filter the DataFrame to display only the records of employees who identify as 'Black or African American
black_african_american=df[df['Ethnicity'].isin(['Black or African American'])]
black_african_american
# Out:
#      EmployeeID         EmployeeName      Gender  Age      BusinessTravel  \
# 6     D906-B674           Uta Melmar      Female   42          No Travel
# 8     3D71-8DC2     Alix Blazejewski        Male   38         Some Travel
# 15    5C03-1009    Willetta Lurriman      Female   42         Some Travel
# 23    B3AF-7E58       Elvira Ianelli      Female   45         Some Travel
# 30    00D4-DD53           Joyce Goor      Female   30  Frequent Traveller
# ...         ...                  ...         ...  ...                 ...
# 1465  467E-977A        Jud Melanaphy        Male   20         Some Travel
# 1466  6FB9-A624          Marc Calver  Non-Binary   27         Some Travel
# 1467  EBF4-5928  Rudolph MacDearmont        Male   21         Some Travel
# 1468  60E6-B1D9           Merill Agg        Male   21         Some Travel
# 1469  84D4-D4C3        Naoma Hebbard      Female   20          No Travel
#
#            Department  DistanceFromHome (KM) State                  Ethnicity  \
# ...

# %%
# Q) filter the DataFrame to show only the employees who are classified as 'Frequent Travellers' in the 'BusinessTravel' category
frqun_travel=df[df['BusinessTravel'].isin(['Frequent Traveller'])]
frqun_travel
# Out:
#      EmployeeID          EmployeeName             Gender  Age  \
# 9     5476-CA0D          Kayley Snoad             Female   31
# 18    ED73-F078    Ernaline Napolione             Female   45
# 20    D7EE-56FC        Zsa zsa Evered             Female   39
# 29    D565-284D        Bessie Bellson             Female   47
# 30    00D4-DD53            Joyce Goor             Female   30
# ...         ...                   ...                ...  ...
# 1444  C472-DAAD           Raf Laraway         Non-Binary   18
# 1449  A08B-F4B1      Antone Pinchback               Male   33
# 1450  8695-09EC          Lyda Everall             Female   33
# 1453  23B5-93C9      Carlita Ivanenko  Prefer Not To Say   31
# 1458  06B1-2653  Montgomery Galliford               Male   19
#
#           BusinessTravel  Department  DistanceFromHome (KM) State  \
# 9     Frequent Traveller  Technology                      4    NY
# 18    Frequent Traveller  Technology                     19    NY
# ...

# %%
# Q) filter the DataFrame to exclude employees from the states 'CA' and 'NY'
excluded_state=['CA','NY']
remain_state=df[~df['State'].isin(excluded_state)]
remain_state
# Out:
#      EmployeeID       EmployeeName      Gender  Age      BusinessTravel  \
# 0     3012-1A41     Leonelle Simco      Female   30         Some Travel
# 3     47A0-559B  Ermentrude Berrie  Non-Binary   39         Some Travel
# 8     3D71-8DC2   Alix Blazejewski        Male   38         Some Travel
# 13    111D-E5EF        Edna Alison  Non-Binary   37         Some Travel
# 15    5C03-1009  Willetta Lurriman      Female   42         Some Travel
# ...         ...                ...         ...  ...                 ...
# 1441  611A-F218      Kenna Dougary      Female   20         Some Travel
# 1444  C472-DAAD        Raf Laraway  Non-Binary   18  Frequent Traveller
# 1445  3E4A-F28F      Rubi Hawkwood      Female   20         Some Travel
# 1450  8695-09EC       Lyda Everall      Female   33  Frequent Traveller
# 1452  FF42-EA28     Madella Worham      Female   18         Some Travel
#
#       Department  DistanceFromHome (KM) State                  Ethnicity  \
# ...

# %%
df['JobRole'].unique()
# Out:
# array(['Sales Executive', 'HR Business Partner', 'Engineering Manager',
#        'Recruiter', 'Data Scientist', 'Machine Learning Engineer',
#        'Manager', 'Software Engineer', 'Senior Software Engineer',
#        'Sales Representative', 'Analytics Manager', 'HR Executive',
#        'HR Manager'], dtype=object)

# %%
# Q) filter the DataFrame to exclude employees from the 'HR' and 'Sales' departments
exclude_employee=['HR Business Partner','Sales Representative','HR Executive','HR Manager']
others=df[~df['JobRole'].isin(exclude_employee)]
others
# Out:
#      EmployeeID         EmployeeName      Gender  Age BusinessTravel  \
# 0     3012-1A41       Leonelle Simco      Female   30    Some Travel
# 1     CBCB-9C9D        Leonerd Aland        Male   38    Some Travel
# 3     47A0-559B    Ermentrude Berrie  Non-Binary   39    Some Travel
# 4     42CC-040A         Stace Savege      Female   29    Some Travel
# 5     C219-6C2E  Clerkclaude Hinkins        Male   34    Some Travel
# ...         ...                  ...         ...  ...            ...
# 1465  467E-977A        Jud Melanaphy        Male   20    Some Travel
# 1466  6FB9-A624          Marc Calver  Non-Binary   27    Some Travel
# 1467  EBF4-5928  Rudolph MacDearmont        Male   21    Some Travel
# 1468  60E6-B1D9           Merill Agg        Male   21    Some Travel
# 1469  84D4-D4C3        Naoma Hebbard      Female   20     No Travel
#
#            Department  DistanceFromHome (KM) State  \
# 0               Sales                     27    IL
# ...

# %%
df['HireMonth_Name'].unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
# Q) ilter the DataFrame to include only records where the 'HireMonth_Name' is either 'January', 'March', or 'April'
month=['January','March','April']
rest_month=df[df['HireMonth_Name'].isin(month)]
rest_month
# Out:
#      EmployeeID         EmployeeName      Gender  Age      BusinessTravel  \
# 0     3012-1A41       Leonelle Simco      Female   30         Some Travel
# 1     CBCB-9C9D        Leonerd Aland        Male   38         Some Travel
# 2     95D7-1CE9          Ahmed Sykes        Male   43         Some Travel
# 3     47A0-559B    Ermentrude Berrie  Non-Binary   39         Some Travel
# 4     42CC-040A         Stace Savege      Female   29         Some Travel
# ...         ...                  ...         ...  ...                 ...
# 1364  7CFC-C4DA         Brant Damper        Male   21         Some Travel
# 1365  A409-0113        Aurthur Attoe        Male   27         Some Travel
# 1366  543B-0EE5  Theodore Parrington        Male   20         Some Travel
# 1367  4795-4D3F          Tammy Flaws        Male   20         Some Travel
# 1368  BE54-B2AF     Nelia Abramowitz      Female   20  Frequent Traveller
#
#            Department  DistanceFromHome (KM) State                Ethnicity  \
# ...

# %% [markdown]
# ## reset_index()

# %%
job_status.reset_index(drop=True,inplace=True)
job_status
# Out:
#                         EmployeeName                    JobRole
# 0                       Joyan Brason            Sales Executive
# 1                        Edna Alison          Software Engineer
# 2                        Amye Townes             Data Scientist
# 3                     Muffin Ellcome          Software Engineer
# 4    Jodie Le Breton De La Vieuville  Machine Learning Engineer
# ..                               ...                        ...
# 131                Greer MacDearmaid            Sales Executive
# 132                     Erny Waywell   Senior Software Engineer
# 133                       Layton Ord            Sales Executive
# 134                      Ava Galland               HR Executive
# 135                    Symon Raisher   Senior Software Engineer
#
# [136 rows x 2 columns]

# %%
tech_salary_high.reset_index(drop=True,inplace=True)
tech_salary_high
# Out:
#     EmployeeID       EmployeeName             Gender  Age      BusinessTravel  \
# 0    47A0-559B  Ermentrude Berrie         Non-Binary   39         Some Travel
# 1    D906-B674         Uta Melmar             Female   42          No Travel
# 2    73CF-4956      Hannis Waslin             Female   32         Some Travel
# 3    277A-A6FA    Annabela Pablos             Female   35         Some Travel
# 4    97F4-0B14      Vernen Powner               Male   33         Some Travel
# ..         ...                ...                ...  ...                 ...
# 441  23B5-93C9   Carlita Ivanenko  Prefer Not To Say   31  Frequent Traveller
# 442  9160-043F     Jemie Tasseler             Female   29         Some Travel
# 443  542E-321D    Spencer Gabitis               Male   30          No Travel
# 444  8B55-CBEC      Symon Raisher               Male   40         Some Travel
# 445  6FB9-A624        Marc Calver         Non-Binary   27         Some Travel
#
# ...

# %%
dep_sls_hr.reset_index(drop=True,inplace=True)
dep_sls_hr
# Out:
#    EmployeeID       EmployeeName  Gender  Age      BusinessTravel  \
# 0   95D7-1CE9        Ahmed Sykes    Male   43         Some Travel
# 1   BD1B-53A3     Wendall Dryden    Male   43         Some Travel
# 2   DFA9-990E       Cale Holston    Male   43          No Travel
# 3   B3AF-7E58     Elvira Ianelli  Female   45         Some Travel
# 4   D565-284D     Bessie Bellson  Female   47  Frequent Traveller
# ..        ...                ...     ...  ...                 ...
# 76  0BEE-FC20    Sherill Covotti  Female   49         Some Travel
# 77  0C54-705D      Grata Yannoni  Female   50         Some Travel
# 78  A663-B3DF      Wynny Pechell  Female   41  Frequent Traveller
# 79  C3C0-349E         Isac Dreus    Male   45         Some Travel
# 80  921D-AE10  Greer MacDearmaid  Female   46          No Travel
#
#          Department  DistanceFromHome (KM) State  \
# 0   Human Resources                     29    CA
# 1             Sales                     27    CA
# ...

# %%
sls_age30_slryhigh.reset_index(drop=True,inplace=True)
sls_age30_slryhigh
# Out:
#              EmployeeName  YearsAtCompany
# 0           Leonerd Aland              10
# 1     Clerkclaude Hinkins              10
# 2            Joyan Brason              10
# 3        Alix Blazejewski              10
# 4             Torey Abram              10
# ..                    ...             ...
# 127       Torre Blazynski               0
# 128            Layton Ord               0
# 129       Kane Skillicorn               0
# 130        Tracey Joynson               0
# 131  Selestina Ferrarello               0
#
# [132 rows x 2 columns]

# %%
hr_age35_frqtrvl.reset_index(drop=True,inplace=True)
hr_age35_frqtrvl
# Out:
#   EmployeeID      EmployeeName      Gender  Age      BusinessTravel  \
# 0  B6EC-313E     Corbin Gooddy        Male   26  Frequent Traveller
# 1  F5E3-48BB     Zenia Rattery      Female   25  Frequent Traveller
# 2  0CFA-28A3        Duff Rioch        Male   21  Frequent Traveller
# 3  55A7-8D82       Allyn Glyde  Non-Binary   23  Frequent Traveller
# 4  B0C8-E3DF  Eleanor Escalero      Female   19  Frequent Traveller
# 5  BEBB-3E92    Flinn Redferne        Male   24  Frequent Traveller
# 6  F469-0427    Krissie Albery      Female   19  Frequent Traveller
#
#         Department  DistanceFromHome (KM) State  \
# 0  Human Resources                     17    CA
# 1  Human Resources                      3    CA
# 2  Human Resources                     42    CA
# 3  Human Resources                     34    NY
# 4  Human Resources                     24    IL
# 5  Human Resources                     17    CA
# 6  Human Resources                     31    NY
#
# ...

# %% [markdown]
# ## set_index()

# %%
df1=df1.set_index(['Education'])
df1
# Out:
#                   EmployeeName      Gender  Age      BusinessTravel  \
# Education
# 5               Leonelle Simco      Female   30         Some Travel
# 4                Leonerd Aland        Male   38         Some Travel
# 4                  Ahmed Sykes        Male   43         Some Travel
# 3            Ermentrude Berrie  Non-Binary   39         Some Travel
# 2                 Stace Savege      Female   29         Some Travel
# 2          Clerkclaude Hinkins        Male   34         Some Travel
# 3                   Uta Melmar      Female   42          No Travel
# 2                 Joyan Brason      Female   40         Some Travel
# 4             Alix Blazejewski        Male   38         Some Travel
# 2                 Kayley Snoad      Female   31  Frequent Traveller
# 4                Hannis Waslin      Female   32         Some Travel
#
#                 Department  DistanceFromHome (KM) State  \
# Education
# 5                    Sales                     27    IL
# ...

# %%
df2=df2.set_index(['Department'])
df2
# Out:
#                         EmployeeName      Gender  Age BusinessTravel
# Department
# Sales                 Leonelle Simco      Female   30    Some Travel
# Sales                  Leonerd Aland        Male   38    Some Travel
# Human Resources          Ahmed Sykes        Male   43    Some Travel
# Technology         Ermentrude Berrie  Non-Binary   39    Some Travel
# Human Resources         Stace Savege      Female   29    Some Travel
# ...                              ...         ...  ...            ...
# Technology             Jud Melanaphy        Male   20    Some Travel
# Technology               Marc Calver  Non-Binary   27    Some Travel
# Sales            Rudolph MacDearmont        Male   21    Some Travel
# Technology                Merill Agg        Male   21    Some Travel
# Technology             Naoma Hebbard      Female   20     No Travel
#
# [1470 rows x 4 columns]

# %%
df3=df3.set_index(['DistanceFromHome (KM)'])
df3
# Out:
#                            EmployeeName State MaritalStatus       Department  \
# DistanceFromHome (KM)
# 11                         Addison Elfe    CA       Married       Technology
# 5                         Darice Excell    NY        Single       Technology
# 36                          Ashli Hales    CA       Married            Sales
# 45                          Conn Mouser    IL      Divorced  Human Resources
# 16                         Mimi Mawditt    NY        Single       Technology
# 24                        Albina Baston    NY       Married       Technology
# 32                         Joya Hefford    NY       Married            Sales
# 9                           Baird Trays    NY      Divorced            Sales
# 21                      Marilee Moreton    CA       Married       Technology
# 26                        Marlin Egdell    CA      Divorced            Sales
# 8                      Filide Summerlie    CA       Married            Sales
# ...

# %%
df4=df4.set_index(['State'])
df4
# Out:
#                EmployeeName      Gender  Age BusinessTravel  Department  \
# State
# NY          Skipper Sambles        Male   47    Some Travel  Technology
# NY       Emmerich Wallicker        Male   47     No Travel        Sales
# CA             Horst Mynett        Male   36    Some Travel  Technology
# CA     Benyamin Wasielewicz        Male   43     No Travel   Technology
# CA            Pierce Birkby        Male   38    Some Travel  Technology
# ...                     ...         ...  ...            ...         ...
# CA            Nanine Barrie      Female   26     No Travel   Technology
# CA          Meade Quinnelly        Male   25    Some Travel  Technology
# CA         Alister Gianullo        Male   27    Some Travel  Technology
# NY            Magnum Dublin  Non-Binary   27    Some Travel  Technology
# CA           Ichabod Mabbot        Male   28    Some Travel       Sales
#
#        DistanceFromHome (KM)                        Ethnicity  Education
# State
# ...

# %%
df5=df5.set_index(['HireYear'])
df5
# Out:
#          EmployeeID       EmployeeName  Gender  Age      BusinessTravel  \
# HireYear
# 2012      42CC-040A       Stace Savege  Female   29         Some Travel
# 2012      D7EE-56FC     Zsa zsa Evered  Female   39  Frequent Traveller
# 2012      151D-1FF2           Kai Lush  Female   34  Frequent Traveller
# 2012      E1B4-9AA1        Ashli Hales  Female   46         Some Travel
# 2012      5237-1B85      Faydra Losbie  Female   28         Some Travel
# 2012      FE2B-3DC7  Mattie Wippermann  Female   28         Some Travel
# 2012      8EE9-E86D        Conn Mouser    Male   46         Some Travel
# 2012      DFE3-6FA7     Eulalie Critch  Female   43  Frequent Traveller
# 2013      4B6E-3C21     Heidie McCrone  Female   32         Some Travel
# 2013      327B-F6D3         Codee Jean  Female   37         Some Travel
# 2013      12F7-BCBB     Clea MacCartan  Female   48  Frequent Traveller
# 2014      5A04-0EB4    Debbie Martinho  Female   27  Frequent Traveller
# ...

# %%
sort.value_counts()
# Out:
# EmployeeName       Department       YearsAtCompany  YearsSinceLastPromotion
# Abra MacGray       Technology       0               0                          1
# Maurise Shaxby     Technology       4               4                          1
# Mattie Wippermann  Technology       5               4                          1
# Matti Liversley    Sales            3               3                          1
# Matthieu Oulet     Sales            5               4                          1
#                                                                               ..
# Farly Drinan       Technology       9               9                          1
# Farica Fardell     Human Resources  7               5                          1
# Fanny Yoell        Technology       0               0                          1
# Fan Pizey          Technology       10              7                          1
# Zsa zsa Valentin   Sales            5               0                          1
# ...

# %% [markdown]
# # Visualizasion

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Age Distribution of Employees

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Age', bins=20, kde=True)
plt.title('Age Distribution of Employees')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Gender Distribution across Departments

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Department', hue='Gender')
plt.title('Gender Distribution across Departments')
plt.xlabel('Department')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Attrition by Business Travel Frequency

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='BusinessTravel', hue='Attrition')
plt.title('Attrition by Business Travel Frequency')
plt.xlabel('Business Travel Frequency')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Stock Option Level vs. Attrition

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='StockOptionLevel', hue='Attrition')
plt.title('Stock Option Level vs. Attrition')
plt.xlabel('Stock Option Level')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Distance from Home vs. Attrition

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='DistanceFromHome (KM)', hue='Attrition', multiple='stack')
plt.title('Distance from Home vs. Attrition')
plt.xlabel('Distance from Home (KM)')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Distribution of Years at Company by Marital Status

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='MaritalStatus', y='YearsAtCompany')
plt.title('Distribution of Years at Company by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Years at Company')
plt.show()

# %% [markdown]
# # Salary vs. Years at Company by Attrition

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='YearsAtCompany', y='Salary', hue='Attrition')
plt.title('Salary vs. Years at Company by Attrition')
plt.xlabel('Years at Company')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# # Suggestions:
# 1.Flexible Work Arrangements: To reduce attrition, especially among employees with high business travel frequency.
#
# 2.Diversity Initiatives: Establish programs for departments with low gender diversity to encourage inclusive hiring.
#
# 3.Retention Programs: Focus on employees with less tenure, as they may benefit from mentorship or development programs.
#
# 4.Salary Adjustments: Use insights from salary distributions to ensure competitive compensation across roles and tenures.

# %% [markdown]
# # Conclusion
# The analysis of the employee dataset reveals key trends and potential areas for improvement in the organization’s HR policies.
# Recommendations focus on improving retention, promoting diversity, and creating a supportive work environment for employees.
# Future analysis could include predictive modeling to anticipate attrition and identify high-risk employees for early intervention.
